# %%
import pandas as pd

# %% [markdown]
# ### Import des fichiers

# %%
2*2
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
toto = 1
tata = toto + 1

# %%
tata
# Out:
# 2

# %%
if toto<4:
    toto = toto +1

# %%
toto
# Out:
# 2

# %%
tata
# Out:
# 2

# %%
customer_data_set = pd.read_csv("olist_customers_dataset.csv")
order_items_dataset = pd.read_csv("olist_order_items_dataset.csv")

# %%
order_payments_dataset = pd.read_csv("olist_order_payments_dataset.csv")
sellers_dataset = pd.read_csv("olist_sellers_dataset.csv")
products_dataset = pd.read_csv("olist_products_dataset.csv")
orders_dataset = pd.read_csv("olist_orders_dataset.csv")

# %%
order_items_dataset
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5       00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6       00054e8431b9d7675808bcb819fb4a32              1
# 7       000576fe39319847cbb9d288c5617fa6              1
# 8       0005a1a1728c9d785b8e2b08b904576c              1
# 9       0005f50442cb953dcd1d21e1fb923495              1
# 10      00061f2a7bc09da83e415a52dc8a4af1              1
# 11      00063b381e2406b52ad429470734ebd5              1
# 12      0006ec9db01a64e59a68b2c340bf65a7              1
# 13      0008288aa423d2a3f00fcb17cd7d8719              1
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 15      0009792311464db532ff765bf7b182ae              1
# ...

# %%
order_payments_dataset.groupby("payment_type").sum()
# Out:
#               payment_sequential  payment_installments  payment_value
# payment_type
# boleto                     19785                 19784   2.869361e+06
# credit_card                77115                269332   1.254208e+07
# debit_card                  1582                  1529   2.179898e+05
# not_defined                    3                     3   0.000000e+00
# voucher                    15029                  5775   3.794369e+05
